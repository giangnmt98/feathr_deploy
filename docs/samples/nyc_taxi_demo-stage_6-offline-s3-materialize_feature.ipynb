# %% [markdown]
# # Feathr Quick Start Notebook
#
# This notebook illustrates the use of Feathr Feature Store to create a model that predicts NYC Taxi fares. The dataset comes from [here](https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page).
#
# The major problems Feathr solves are:
#
# 1. Create, share and manage useful features from raw source data.
# 2. Provide Point-in-time feature join to create training dataset to ensure no data leakage.
# 3. Deploy the same feature data to online store to eliminate training and inference data skew.

# %% [markdown]
# ## Prerequisite
#
# Feathr has native cloud integration. First step is to provision required cloud resources if you want to use Feathr.
#
# Follow the [Feathr ARM deployment guide](https://feathr-ai.github.io/feathr/how-to-guides/azure-deployment-arm.html) to run Feathr on Azure. This allows you to quickly get started with automated deployment using Azure Resource Manager template. For more details, please refer [README.md](https://github.com/feathr-ai/feathr#%EF%B8%8F-running-feathr-on-cloud-with-a-few-simple-steps).
#
# Additionally, to run this notebook, you'll need to install `feathr` pip package. For local spark, simply run `pip install feathr` on the machine that runs this notebook. To use Databricks or Azure Synapse Analytics, please see dependency management documents:
# - [Azure Databricks dependency management](https://learn.microsoft.com/en-us/azure/databricks/libraries/)
# - [Azure Synapse Analytics dependency management](https://learn.microsoft.com/en-us/azure/synapse-analytics/spark/apache-spark-azure-portal-add-libraries)

# %% [markdown]
# ## Notebook Steps
#
# This tutorial demonstrates the key capabilities of Feathr, including:
#
# 1. Install Feathr and necessary dependencies
# 2. Create shareable features with Feathr feature definition configs
# 3. Create training data using point-in-time correct feature join
# 4. Train a prediction model and evaluate the model and features
# 5. Register the features to share across teams
# 6. Materialize feature values for online scoring
#
# The overall data flow is as follows:
#
# <img src="https://raw.githubusercontent.com/feathr-ai/feathr/main/docs/images/feature_flow.png" width="800">

# %% [markdown]
# ## 1. Install Feathr and Necessary Dependancies
#
# Install feathr and necessary packages by running one of following commends if you haven't installed them already:

# %%
# To install feathr from the latest codes in the repo:
#%pip install "git+https://github.com/feathr-ai/feathr.git#subdirectory=feathr_project&egg=feathr[notebook]" 

# To install the latest release:
#%pip install "feathr[notebook]"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datetime import timedelta
import os
from pathlib import Path

from pyspark.ml import Pipeline
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import GBTRegressor
from pyspark.sql import DataFrame, SparkSession
import pyspark.sql.functions as F

import feathr
from feathr import (
    FeathrClient,
    # Feature data types
    BOOLEAN, FLOAT, INT32, ValueType,
    # Feature data sources
    INPUT_CONTEXT, HdfsSource,
    # Feature aggregations
    TypedKey, WindowAggTransformation,
    # Feature types and anchor
    DerivedFeature, Feature, FeatureAnchor,
    # Materialization
    BackfillTime, MaterializationSettings, RedisSink,
    # Offline feature computation
    FeatureQuery, ObservationSettings,
)
from feathr.datasets import nyc_taxi
from feathr.spark_provider.feathr_configurations import SparkExecutionConfiguration
from feathr.utils.config import generate_config
from feathr.utils.job_utils import get_result_df
from feathr.utils.platform import is_databricks, is_jupyter

print(f"Feathr version: {feathr.__version__}")
# Out:
# Feathr version: 1.0.0

# %% [markdown]
# ## 2. Create Shareable Features with Feathr Feature Definition Configs
#
# First, we define all the necessary resource key values for authentication. These values are retrieved by using [Azure Key Vault](https://azure.microsoft.com/en-us/services/key-vault/) cloud key value store. For authentication, we use Azure CLI credential in this notebook, but you may add secrets' list and get permission for the necessary service principal instead of running `az login --use-device-code`.
#
# Please refer to [A note on using azure key vault to store credentials](https://github.com/feathr-ai/feathr/blob/41e7496b38c43af6d7f8f1de842f657b27840f6d/docs/how-to-guides/feathr-configuration-and-env.md#a-note-on-using-azure-key-vault-to-store-credentials) for more details.

# %%
RESOURCE_PREFIX = None  # TODO fill the value used to deploy the resources via ARM template
PROJECT_NAME = "nyc_taxi"

# Currently support: 'azure_synapse', 'databricks', and 'local' 
SPARK_CLUSTER = "local"

# TODO fill values to use databricks cluster:
DATABRICKS_CLUSTER_ID = None             # Set Databricks cluster id to use an existing cluster
if is_databricks():
    # If this notebook is running on Databricks, its context can be used to retrieve token and instance URL
    ctx = dbutils.notebook.entry_point.getDbutils().notebook().getContext()
    DATABRICKS_WORKSPACE_TOKEN_VALUE = ctx.apiToken().get()
    SPARK_CONFIG__DATABRICKS__WORKSPACE_INSTANCE_URL = f"https://{ctx.tags().get('browserHostName').get()}"
else:
    DATABRICKS_WORKSPACE_TOKEN_VALUE = None                  # Set Databricks workspace token to use databricks
    SPARK_CONFIG__DATABRICKS__WORKSPACE_INSTANCE_URL = None  # Set Databricks workspace url to use databricks

# TODO fill values to use Azure Synapse cluster:
AZURE_SYNAPSE_SPARK_POOL = None  # Set Azure Synapse Spark pool name
AZURE_SYNAPSE_URL = None         # Set Azure Synapse workspace url to use Azure Synapse
ADLS_KEY = None                  # Set Azure Data Lake Storage key to use Azure Synapse

# An existing Feathr config file path. If None, we'll generate a new config based on the constants in this cell.
FEATHR_CONFIG_PATH = None

# If set True, use an interactive browser authentication to get the redis password.
USE_CLI_AUTH = False

# If set True, register the features to Feathr registry.
REGISTER_FEATURES = False

# (For the notebook test pipeline) If true, use ScrapBook package to collect the results.
SCRAP_RESULTS = False

# %% [markdown]
# To use Databricks as the feathr client's target platform, you may need to set a databricks token to an environment variable like:
#
# `export DATABRICKS_WORKSPACE_TOKEN_VALUE=your-token`
#
# or in the notebook cell,
#
# `os.environ["DATABRICKS_WORKSPACE_TOKEN_VALUE"] = your-token`
#
# If you are running this notebook on Databricks, the token will be automatically retrieved by using the current Databricks notebook context.
#
# On the other hand, to use Azure Synapse cluster, you have to specify the synapse workspace storage key:
#
# `export ADLS_KEY=your-key`
#
# or in the notebook cell,
#
# `os.environ["ADLS_KEY"] = your-key`

# %%
if SPARK_CLUSTER == "azure_synapse" and not os.environ.get("ADLS_KEY"):
    os.environ["ADLS_KEY"] = ADLS_KEY
elif SPARK_CLUSTER == "databricks" and not os.environ.get("DATABRICKS_WORKSPACE_TOKEN_VALUE"):
    os.environ["DATABRICKS_WORKSPACE_TOKEN_VALUE"] = DATABRICKS_WORKSPACE_TOKEN_VALUE

# %%
# Get an authentication credential to access Azure resources and register features
if USE_CLI_AUTH:
    # Use AZ CLI interactive browser authentication
    # !az login --use-device-code
    from azure.identity import AzureCliCredential
    credential = AzureCliCredential(additionally_allowed_tenants=['*'],)
elif "AZURE_TENANT_ID" in os.environ and "AZURE_CLIENT_ID" in os.environ and "AZURE_CLIENT_SECRET" in os.environ:
    # Use Environment variable secret
    from azure.identity import EnvironmentCredential
    credential = EnvironmentCredential()
else:
    # Try to use the default credential
    from azure.identity import DefaultAzureCredential
    credential = DefaultAzureCredential(
        exclude_interactive_browser_credential=False,
        additionally_allowed_tenants=['*'],
    )

# %% [markdown]
# ### Configurations
#
# Feathr uses a yaml file to define configurations. Please refer to [feathr_config.yaml]( https://github.com//feathr-ai/feathr/blob/main/feathr_project/feathrcli/data/feathr_user_workspace/feathr_config.yaml) for the meaning of each field.
#
# All the Feathr configurations can be set to the yaml file via keyword arguments of `generate_config` helper function. Each keyword argument should be the concatenation of different layers of the config name using `__` as a separator.
# For example, if you want to specify a different value for the feature registry api endpoint, you can pass `        feature_registry__api_endpoint="YOUR-API-ENDPOINT-URL"`.
#
# Note, a default value for the api endpoint will be set based on `RESOURCE_PREFIX`.

# %%
print(feathr.__version__)
os.environ['S3_ENDPOINT'] = "127.0.0.1:9000"
os.environ['S3_ACCESS_KEY'] = "3Uu5nPtNBjKLtHov89dD"
os.environ['S3_SECRET_KEY'] = "fd3YycgUgZkIQPTayGStql9MX4j8Z1sctc19iOh1"
os.environ['SPARK_LOCAL_IP'] = "127.0.0.1"
os.environ['REDIS_PASSWORD'] = "foobared"  # default password for Redis
# Out:
# 1.0.0

# %% [markdown]
# All the configurations can be overwritten by environment variables with concatenation of `__` for different layers of the config file, same as how you may pass the keyword arguments to `generate_config` utility function.
#
# For example, `feathr_runtime_location` for databricks config can be overwritten by setting `spark_config__databricks__feathr_runtime_location` environment variable.

# %% [markdown]
# ### Initialize Feathr client

# %%
from pathlib import Path
feathr_workspace_folder = Path(f"./{PROJECT_NAME}_feathr_config.yaml")
client = FeathrClient(str(feathr_workspace_folder))
# Out:
# 2024-09-06 16:50:28.202 | INFO     | feathr.utils._env_config_reader:get:62 - Config secrets__azure_key_vault__name is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:28.203 | INFO     | feathr.utils._env_config_reader:get:62 - Config offline_store__s3__s3_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:28.205 | INFO     | feathr.utils._env_config_reader:get:62 - Config offline_store__adls__adls_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:28.205 | INFO     | feathr.utils._env_config_reader:get:62 - Config offline_store__wasb__wasb_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:28.205 | INFO     | feathr.utils._env_config_reader:get:62 - Config offline_store__jdbc__jdbc_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:28.206 | INFO     | feathr.utils._env_config_reader:get:62 - Config offline_store__snowflake__snowflake_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# No offline storage enabled.
# 2024-09-06 16:50:28.207 | INFO     | feathr.utils._env_config_reader:get:62 - Config spark_config__local__workspace is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:28.207 | INFO     | feathr.utils._env_config_reader:get:62 - Config feature_registry__purview__purview_name is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:28.207 | INFO     | feathr.client:__init__:208 - Feathr client 1.0.0 initialized successfully.

# %% [markdown]
# ### Prepare the NYC taxi fare dataset

# %%
# # If the notebook is runnong on Jupyter, start a spark session:
# if is_jupyter():
#     spark = (
#         SparkSession
#         .builder
#         .appName("feathr")
#         .config("spark.jars.packages", "org.apache.spark:spark-avro_2.12:3.3.0,io.delta:delta-core_2.12:2.1.1")
#         .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
#         .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
#         .config("spark.ui.port", "8080")  # Set ui port other than the default one (4040) so that feathr spark job doesn't fail. 
#         .getOrCreate()
#     )

# # Else, you must already have a spark session object available in databricks or synapse notebooks.

# %%
# Use dbfs if the notebook is running on Databricks
if is_databricks():
    WORKING_DIR = f"/dbfs/{PROJECT_NAME}"
else:
    WORKING_DIR = PROJECT_NAME

# %%
# # Download the data file
# data_file_path = "../../feathr_project/test/test_user_workspace/green_tripdata_2020-04_with_index.csv"
# df_raw = nyc_taxi.get_spark_df(spark=spark, local_cache_path=data_file_path)
# df_raw.limit(5).show()

# %%
TIMESTAMP_COL = "lpep_dropoff_datetime"
TIMESTAMP_FORMAT = "yyyy-MM-dd HH:mm:ss"

# %%
# # Upload files to cloud if needed
# if client.spark_runtime == "local":
#     # In local mode, we can use the same data path as the source.
#     data_source_path = data_file_path
# elif client.spark_runtime == "databricks" and is_databricks():
#     # If the notebook is running on databricks, we can use the same data path as the source.
#     data_source_path = data_file_path.replace("/dbfs", "dbfs:", 1)
# else:
#     # Otherwise, upload the local file to the cloud storage (either dbfs or adls).
#     data_source_path = client.feathr_spark_launcher.upload_or_get_cloud_path(data_file_path)

# %% [markdown]
# # Get features from register server

# %%
feature_dict = client.get_features_from_registry(project_name=PROJECT_NAME, return_keys=True, verbose=True)
# Out:
# 2024-09-06 16:50:28.867 | INFO     | feathr.client:get_features_from_registry:1147 - Get anchor features from registry:
# 2024-09-06 16:50:28.868 | INFO     | feathr.client:get_features_from_registry:1153 - {
#   "name": "f_trip_distance",
#   "featureType": {
#     "type": "TENSOR",
#     "tensorCategory": "DENSE",
#     "dimensionType": [],
#     "valType": "FLOAT"
#   },
#   "key": [
#     {
#       "keyColumn": "NOT_NEEDED",
#       "keyColumnType": "UNSPECIFIED",
#       "fullName": "feathr.dummy_typedkey",
#       "description": "feathr.dummy_typedkey",
#       "keyColumnAlias": "NOT_NEEDED"
#     }
#   ],
#   "transformation": {
#     "transformExpr": "trip_distance"
#   }
# }
# 2024-09-06 16:50:28.869 | INFO     | feathr.client:get_features_from_registry:1153 - {
#   "name": "f_trip_time_duration",
#   "featureType": {
#     "type": "TENSOR",
#     "tensorCategory": "DENSE",
#     "dimensionType": [],
#     "valType": "FLOAT"
#   },
#   "key": [
#     {
#       "keyColumn": "NOT_NEEDED",
#       "keyColumnType": "UNSPECIFIED",
#       "fullName": "feathr.dummy_typedkey",
#       "description": "feathr.dummy_typedkey",
#       "keyColumnAlias": "NOT_NEEDED"
#     }
#   ],
#   "transformation": {
#     "transformExpr": "cast_float((to_unix_timestamp(lpep_dropoff_datetime) - to_unix_timestamp(lpep_pickup_datetime)) / 60)"
#   }
# }
# 2024-09-06 16:50:28.869 | INFO     | feathr.client:get_features_from_registry:1153 - {
#   "name": "f_is_long_trip_distance",
#   "featureType": {
#     "type": "TENSOR",
#     "tensorCategory": "DENSE",
#     "dimensionType": [],
#     "valType": "BOOLEAN"
#   },
#   "key": [
#     {
#       "keyColumn": "NOT_NEEDED",
#       "keyColumnType": "UNSPECIFIED",
#       "fullName": "feathr.dummy_typedkey",
#       "description": "feathr.dummy_typedkey",
#       "keyColumnAlias": "NOT_NEEDED"
#     }
#   ],
#   "transformation": {
#     "transformExpr": "trip_distance > 30.0"
#   }
# }
# 2024-09-06 16:50:28.870 | INFO     | feathr.client:get_features_from_registry:1153 - {
#   "name": "f_day_of_week",
#   "featureType": {
#     "type": "TENSOR",
#     "tensorCategory": "DENSE",
#     "dimensionType": [],
#     "valType": "INT"
#   },
#   "key": [
#     {
#       "keyColumn": "NOT_NEEDED",
#       "keyColumnType": "UNSPECIFIED",
#       "fullName": "feathr.dummy_typedkey",
#       "description": "feathr.dummy_typedkey",
#       "keyColumnAlias": "NOT_NEEDED"
#     }
#   ],
#   "transformation": {
#     "transformExpr": "dayofweek(lpep_dropoff_datetime)"
#   }
# }
# 2024-09-06 16:50:28.870 | INFO     | feathr.client:get_features_from_registry:1153 - {
#   "name": "f_day_of_month",
#   "featureType": {
#     "type": "TENSOR",
#     "tensorCategory": "DENSE",
#     "dimensionType": [],
#     "valType": "INT"
#   },
#   "key": [
#     {
#       "keyColumn": "NOT_NEEDED",
#       "keyColumnType": "UNSPECIFIED",
#       "fullName": "feathr.dummy_typedkey",
#       "description": "feathr.dummy_typedkey",
#       "keyColumnAlias": "NOT_NEEDED"
#     }
#   ],
#   "transformation": {
#     "transformExpr": "dayofmonth(lpep_dropoff_datetime)"
#   }
# }
# 2024-09-06 16:50:28.871 | INFO     | feathr.client:get_features_from_registry:1153 - {
#   "name": "f_hour_of_day",
#   "featureType": {
#     "type": "TENSOR",
#     "tensorCategory": "DENSE",
#     "dimensionType": [],
#     "valType": "INT"
#   },
#   "key": [
#     {
#       "keyColumn": "NOT_NEEDED",
#       "keyColumnType": "UNSPECIFIED",
#       "fullName": "feathr.dummy_typedkey",
#       "description": "feathr.dummy_typedkey",
#       "keyColumnAlias": "NOT_NEEDED"
#     }
#   ],
#   "transformation": {
#     "transformExpr": "hour(lpep_dropoff_datetime)"
#   }
# }
# 2024-09-06 16:50:28.871 | INFO     | feathr.client:get_features_from_registry:1153 - {
#   "name": "f_location_avg_fare",
#   "featureType": {
#     "type": "TENSOR",
#     "tensorCategory": "DENSE",
#     "dimensionType": [],
#     "valType": "FLOAT"
#   },
#   "key": [
#     {
#       "keyColumn": "DOLocationID",
#       "keyColumnType": "INT",
#       "fullName": "nyc_taxi.location_id",
#       "description": "nyc_taxi.location_id",
#       "keyColumnAlias": "DOLocationID"
#     }
#   ],
#   "transformation": {
#     "defExpr": "fare_amount_cents",
#     "aggFunc": "AVG",
#     "window": "90d"
#   }
# }
# 2024-09-06 16:50:28.872 | INFO     | feathr.client:get_features_from_registry:1153 - {
#   "name": "f_location_max_fare",
#   "featureType": {
#     "type": "TENSOR",
#     "tensorCategory": "DENSE",
#     "dimensionType": [],
#     "valType": "FLOAT"
#   },
#   "key": [
#     {
#       "keyColumn": "DOLocationID",
#       "keyColumnType": "INT",
#       "fullName": "nyc_taxi.location_id",
#       "description": "nyc_taxi.location_id",
#       "keyColumnAlias": "DOLocationID"
#     }
#   ],
#   "transformation": {
#     "defExpr": "fare_amount_cents",
#     "aggFunc": "MAX",
#     "window": "90d"
#   }
# }
# 2024-09-06 16:50:28.872 | INFO     | feathr.client:get_features_from_registry:1155 - Get derived features from registry:
# 2024-09-06 16:50:28.873 | INFO     | feathr.client:get_features_from_registry:1160 - {
#   "name": "f_trip_speed",
#   "featureType": {
#     "type": "TENSOR",
#     "tensorCategory": "DENSE",
#     "dimensionType": [],
#     "valType": "FLOAT"
#   },
#   "key": [
#     {
#       "keyColumn": "NOT_NEEDED",
#       "keyColumnType": "UNSPECIFIED",
#       "fullName": "feathr.dummy_typedkey",
#       "description": "feathr.dummy_typedkey",
#       "keyColumnAlias": "NOT_NEEDED"
#     }
#   ],
#   "inputAnchorFeatures": [
#     "67a74383-ab2d-4621-894e-51a4c4f79770",
#     "bda71a00-67b9-49f2-8e35-51efc3f484e1"
#   ],
#   "inputDerivedFeatures": [],
#   "transformation": {
#     "transformExpr": "f_trip_distance / f_trip_time_duration"
#   }
# }

# %%
[feat.name for feat in list(feature_dict[0].values())]
# Out:
# ['f_trip_distance',
#  'f_trip_time_duration',
#  'f_is_long_trip_distance',
#  'f_day_of_week',
#  'f_day_of_month',
#  'f_hour_of_day',
#  'f_location_avg_fare',
#  'f_location_max_fare',
#  'f_trip_speed']

# %%
[type_key.key_column for type_keys in list(feature_dict[1].values()) for type_key in type_keys]
# Out:
# ['NOT_NEEDED',
#  'NOT_NEEDED',
#  'NOT_NEEDED',
#  'NOT_NEEDED',
#  'NOT_NEEDED',
#  'NOT_NEEDED',
#  'DOLocationID',
#  'DOLocationID',
#  'NOT_NEEDED']

# %% [markdown]
# # Materialize Feature Values for Offline Scoring - HDFS

# %%
from datetime import datetime
from feathr import HdfsSink

# %%
FEATURE_TABLE_NAME = "nycTaxiDemoFeature"

# Time range to materialize
backfill_time = BackfillTime(start=datetime(2020, 4, 19), end=datetime(2020, 4, 20), step=timedelta(days=1))

# Destinations:
# For offline store,
hdfs_sink = HdfsSink(output_path="s3a://feathrstore")
settings = MaterializationSettings(
    name=FEATURE_TABLE_NAME + ".job",  # job name
    backfill_time=backfill_time,
    sinks=[hdfs_sink],  # or adls_sink
    feature_names=['f_location_avg_fare',
                     'f_location_max_fare',],
)

client.materialize_features(
    settings=settings,
    execution_configurations={"spark.feathr.outputFormat": "parquet",
                              "spark.feathr.hdfs.local.enable": "true",
                              "spark.hadoop.fs.s3a.endpoint": "http://127.0.0.1:9000",
                              "spark.hadoop.fs.s3a.impl": "org.apache.hadoop.fs.s3a.S3AFileSystem",
                              "spark.hadoop.fs.s3a.path.style.access": "true",
                              'spark.hadoop.fs.s3a.aws.credentials.provider':'org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider',
                               "spark.jars.plus.packages": 
                                                       "io.minio:spark-select_2.11:2.1,org.apache.hadoop:hadoop-aws:3.3.2"
                             
                             },
)

client.wait_job_to_finish(timeout_sec=5000)
# Out:
# 2024-09-06 16:50:29.284 | WARNING  | feathr.utils._env_config_reader:get_from_env_or_akv:88 - Config KAFKA_SASL_JAAS_CONFIG is not found in the environment variable or the remote key value store.
# 2024-09-06 16:50:29.284 | INFO     | feathr.utils._env_config_reader:get:62 - Config monitoring__database__sql__url is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:29.285 | INFO     | feathr.utils._env_config_reader:get:62 - Config monitoring__database__sql__user is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:29.285 | WARNING  | feathr.utils._env_config_reader:get_from_env_or_akv:88 - Config MONITORING_DATABASE_SQL_PASSWORD is not found in the environment variable or the remote key value store.
# 2024-09-06 16:50:29.286 | WARNING  | feathr.spark_provider._localspark_submission:submit_feathr_job:78 - Local Spark Mode only support basic params right now and should be used only for testing purpose.
# 2024-09-06 16:50:29.286 | INFO     | feathr.spark_provider._localspark_submission:_get_debug_file_name:296 - Spark log path is debug/nyc_taxi_feathr_feature_materialization_job20240906165029
# 2024-09-06 16:50:29.287 | INFO     | feathr.spark_provider._localspark_submission:_init_args:271 - Spark job: nyc_taxi_feathr_feature_materialization_job is running on local spark with master: local[*].
# 2024-09-06 16:50:29.292 | INFO     | feathr.spark_provider._localspark_submission:submit_feathr_job:151 - Detail job stdout and stderr are in debug/nyc_taxi_feathr_feature_materialization_job20240906165029/log.
# bash: /mnt/e/setup/miniconda3/lib/libtinfo.so.6: no version information available (required by bash)
# 2024-09-06 16:50:29.294 | INFO     | feathr.spark_provider._localspark_submission:submit_feathr_job:161 - Local Spark job submit with pid: 122409.
# bash: /mnt/e/setup/miniconda3/lib/libtinfo.so.6: no version information available (required by bash)
# 2024-09-06 16:50:29.317 | WARNING  | feathr.utils._env_config_reader:get_from_env_or_akv:88 - Config KAFKA_SASL_JAAS_CONFIG is not found in the environment variable or the remote key value store.
# 2024-09-06 16:50:29.318 | INFO     | feathr.utils._env_config_reader:get:62 - Config monitoring__database__sql__url is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:29.318 | INFO     | feathr.utils._env_config_reader:get:62 - Config monitoring__database__sql__user is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2024-09-06 16:50:29.319 | WARNING  | feathr.utils._env_config_reader:get_from_env_or_akv:88 - Config MONITORING_DATABASE_SQL_PASSWORD is not found in the environment variable or the remote key value store.
# 2024-09-06 16:50:29.319 | WARNING  | feathr.spark_provider._localspark_submission:submit_feathr_job:78 - Local Spark Mode only support basic params right now and should be used only for testing purpose.
# 2024-09-06 16:50:29.320 | INFO     | feathr.spark_provider._localspark_submission:_get_debug_file_name:296 - Spark log path is debug/nyc_taxi_feathr_feature_materialization_job20240906165029
# 2024-09-06 16:50:29.321 | INFO     | feathr.spark_provider._localspark_submission:_init_args:271 - Spark job: nyc_taxi_feathr_feature_materialization_job is running on local spark with master: local[*].
# 2024-09-06 16:50:29.328 | INFO     | feathr.spark_provider._localspark_submission:submit_feathr_job:151 - Detail job stdout and stderr are in debug/nyc_taxi_feathr_feature_materialization_job20240906165029/log.
# bash: /mnt/e/setup/miniconda3/lib/libtinfo.so.6: no version information available (required by bash)
# 2024-09-06 16:50:29.329 | INFO     | feathr.spark_provider._localspark_submission:submit_feathr_job:161 - Local Spark job submit with pid: 122423.
# 2024-09-06 16:50:29.330 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:171 - 2 local spark job(s) in this Launcher, only the latest will be monitored.
# 2024-09-06 16:50:29.331 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:172 - Please check auto generated spark command in debug/nyc_taxi_feathr_feature_materialization_job20240906165029/command.sh and detail logs in debug/nyc_taxi_feathr_feature_materialization_job20240906165029/log.
# bash: /mnt/e/setup/miniconda3/lib/libtinfo.so.6: no version information available (required by bash)
# https://repository.mulesoft.org/nexus/content/repositories/public/ added as a remote repository with the name: repo-1
# https://linkedin.jfrog.io/artifactory/open-source/ added as a remote repository with the name: repo-2
# https://repository.mulesoft.org/nexus/content/repositories/public/ added as a remote repository with the name: repo-1
# https://linkedin.jfrog.io/artifactory/open-source/ added as a remote repository with the name: repo-2
# Ivy Default Cache set to: /home/cuong/.ivy2/cache
# The jars for the packages stored in: /home/cuong/.ivy2/jars
# org.apache.spark#spark-avro_2.12 added as a dependency
# org.apache.logging.log4j#log4j-core added as a dependency
# com.typesafe#config added as a dependency
# org.apache.hadoop#hadoop-mapreduce-client-core added as a dependency
# org.apache.hadoop#hadoop-common added as a dependency
# org.apache.avro#avro added as a dependency
# org.apache.xbean#xbean-asm6-shaded added as a dependency
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# org.apache.kafka#kafka-clients added as a dependency
# com.jasonclawson#jackson-dataformat-hocon added as a dependency
# com.redislabs#spark-redis_2.12 added as a dependency
# org.apache.xbean#xbean-asm6-shaded added as a dependency
# com.google.protobuf#protobuf-java added as a dependency
# commons-io#commons-io added as a dependency
# io.minio#spark-select_2.11 added as a dependency
# org.apache.hadoop#hadoop-aws added as a dependency
# Ivy Default Cache set to: /home/cuong/.ivy2/cache
# The jars for the packages stored in: /home/cuong/.ivy2/jars
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-5105a8c3-e683-4ee0-9a69-6bb3a101a973;1.0
# 	confs: [default]
# org.apache.spark#spark-avro_2.12 added as a dependency
# org.apache.logging.log4j#log4j-core added as a dependency
# com.typesafe#config added as a dependency
# org.apache.hadoop#hadoop-mapreduce-client-core added as a dependency
# org.apache.hadoop#hadoop-common added as a dependency
# org.apache.avro#avro added as a dependency
# org.apache.xbean#xbean-asm6-shaded added as a dependency
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# org.apache.kafka#kafka-clients added as a dependency
# com.jasonclawson#jackson-dataformat-hocon added as a dependency
# com.redislabs#spark-redis_2.12 added as a dependency
# org.apache.xbean#xbean-asm6-shaded added as a dependency
# com.google.protobuf#protobuf-java added as a dependency
# commons-io#commons-io added as a dependency
# io.minio#spark-select_2.11 added as a dependency
# org.apache.hadoop#hadoop-aws added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-78004ccf-8601-42d9-967b-472eca5ca85f;1.0
# 	confs: [default]
# >
# 	found org.apache.spark#spark-avro_2.12;3.3.0 in central
# 	found org.apache.spark#spark-avro_2.12;3.3.0 in central
# 	found org.tukaani#xz;1.8 in central
# 	found org.tukaani#xz;1.8 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found org.apache.logging.log4j#log4j-core;2.17.2 in central
# 	found org.apache.logging.log4j#log4j-core;2.17.2 in central
# 	found com.typesafe#config;1.3.4 in central
# 	found com.typesafe#config;1.3.4 in central
# 	found org.apache.hadoop#hadoop-mapreduce-client-core;3.3.2 in central
# 	found org.apache.hadoop#hadoop-mapreduce-client-core;3.3.2 in central
# 	found org.apache.hadoop#hadoop-yarn-client;3.3.2 in central
# 	found org.apache.hadoop#hadoop-yarn-client;3.3.2 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 in central
# 	found commons-cli#commons-cli;1.2 in central
# 	found commons-cli#commons-cli;1.2 in central
# 	found log4j#log4j;1.2.17 in central
# 	found log4j#log4j;1.2.17 in central
# 	found org.eclipse.jetty.websocket#websocket-client;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-client;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-client;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-client;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-http;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-http;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-io;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-io;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-common;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-api;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-common;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-api;9.4.43.v20210629 in central
# 	found org.apache.hadoop#hadoop-annotations;3.3.2 in central
# 	found org.apache.hadoop#hadoop-annotations;3.3.2 in central
# 	found org.apache.hadoop#hadoop-yarn-api;3.3.2 in central
# 	found org.apache.hadoop#hadoop-yarn-api;3.3.2 in central
# 	found javax.xml.bind#jaxb-api;2.2.11 in central
# 	found javax.xml.bind#jaxb-api;2.2.11 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_7;1.1.1 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_7;1.1.1 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.13.0 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.13.0 in central	found javax.ws.rs#javax.ws.rs-api;2.1.1 in central
#
# 	found javax.ws.rs#javax.ws.rs-api;2.1.1 in central
# 	found org.apache.hadoop#hadoop-yarn-common;3.3.2 in central
# 	found org.apache.hadoop#hadoop-yarn-common;3.3.2 in central
# 	found org.apache.hadoop#hadoop-hdfs-client;3.3.2 in central
# 	found com.squareup.okhttp#okhttp;2.7.5 in central
# 	found org.apache.hadoop#hadoop-hdfs-client;3.3.2 in central
# 	found com.squareup.okhttp#okhttp;2.7.5 in central
# 	found com.squareup.okio#okio;1.6.0 in central
# 	found com.squareup.okio#okio;1.6.0 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.13.0 in central
# x
# 	found com.fasterxml.jackson.core#jackson-core;2.13.0 in central	found com.fasterxml.jackson.core#jackson-databind;2.13.0 in central
#
# 	found com.fasterxml.jackson.core#jackson-core;2.13.0 in central
# 	found org.apache.hadoop#hadoop-auth;3.3.2 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.apache.hadoop#hadoop-auth;3.3.2 in central
# 	found commons-codec#commons-codec;1.11 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.apache.httpcomponents#httpclient;4.5.13 in central
# 	found org.apache.httpcomponents#httpcore;4.4.13 in central
# 	found commons-codec#commons-codec;1.11 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found org.apache.httpcomponents#httpclient;4.5.13 in central
# 	found com.nimbusds#nimbus-jose-jwt;9.8.1 in central
# 	found org.apache.httpcomponents#httpcore;4.4.13 in central
# 	found com.github.stephenc.jcip#jcip-annotations;1.0-1 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found net.minidev#json-smart;2.4.7 in central
# 	found com.nimbusds#nimbus-jose-jwt;9.8.1 in central
# 	found net.minidev#accessors-smart;2.4.7 in central
# 	found com.github.stephenc.jcip#jcip-annotations;1.0-1 in central
# 	found org.ow2.asm#asm;5.0.4 in central
# 	found net.minidev#json-smart;2.4.7 in central
# 	found org.apache.zookeeper#zookeeper;3.5.6 in central
# 	found net.minidev#accessors-smart;2.4.7 in central
# 	found org.apache.zookeeper#zookeeper-jute;3.5.6 in central
# 	found org.ow2.asm#asm;5.0.4 in central
# 	found org.apache.yetus#audience-annotations;0.5.0 in central
# 	found org.apache.zookeeper#zookeeper;3.5.6 in central
# 	found org.apache.curator#curator-framework;4.2.0 in central
# 	found org.apache.zookeeper#zookeeper-jute;3.5.6 in central
# 	found org.apache.curator#curator-client;4.2.0 in central
# 	found org.apache.yetus#audience-annotations;0.5.0 in central
# 	found org.apache.kerby#kerb-simplekdc;1.0.1 in central
# 	found org.apache.curator#curator-framework;4.2.0 in central
# 	found org.apache.kerby#kerb-client;1.0.1 in central
# 	found org.apache.curator#curator-client;4.2.0 in central
# 	found org.apache.kerby#kerby-config;1.0.1 in central
# 	found org.apache.kerby#kerb-simplekdc;1.0.1 in central
# 	found org.apache.kerby#kerb-core;1.0.1 in central	found org.apache.kerby#kerb-client;1.0.1 in central
#
# 	found org.apache.kerby#kerby-pkix;1.0.1 in central
# 	found org.apache.kerby#kerby-config;1.0.1 in central
# 	found org.apache.kerby#kerby-asn1;1.0.1 in central
# 	found org.apache.kerby#kerb-core;1.0.1 in central
# 	found org.apache.kerby#kerby-pkix;1.0.1 in central
# 	found org.apache.kerby#kerby-util;1.0.1 in central
# 	found org.apache.kerby#kerby-asn1;1.0.1 in central
# 	found org.apache.kerby#kerb-common;1.0.1 in central
# 	found org.apache.kerby#kerby-util;1.0.1 in central
# 	found org.apache.kerby#kerb-common;1.0.1 in central
# 	found org.apache.kerby#kerb-crypto;1.0.1 in central
# 	found org.apache.kerby#kerb-crypto;1.0.1 in user-list
# 	found commons-io#commons-io;2.8.0 in central
# 	found commons-io#commons-io;2.8.0 in central
# 	found org.apache.kerby#kerb-util;1.0.1 in central
# 	found org.apache.kerby#kerb-util;1.0.1 in central
# 	found org.apache.kerby#token-provider;1.0.1 in central
# 	found org.apache.kerby#token-provider;1.0.1 in central
# 	found org.apache.kerby#kerb-admin;1.0.1 in central
# 	found org.apache.kerby#kerb-admin;1.0.1 in central
# 	found org.apache.kerby#kerb-server;1.0.1 in central
# 	found org.apache.kerby#kerb-server;1.0.1 in central
# 	found org.apache.kerby#kerb-identity;1.0.1 in central
# 	found org.apache.kerby#kerb-identity;1.0.1 in central
# 	found org.apache.kerby#kerby-xdr;1.0.1 in central
# 	found org.apache.commons#commons-compress;1.21 in central
# 	found org.apache.kerby#kerby-xdr;1.0.1 in central
# 	found javax.servlet#javax.servlet-api;3.1.0 in central
# 	found org.apache.commons#commons-compress;1.21 in central
# 	found javax.servlet#javax.servlet-api;3.1.0 in central
# 	found com.sun.jersey#jersey-core;1.19 in central
# 	found javax.ws.rs#jsr311-api;1.1.1 in central
# 	found com.sun.jersey#jersey-core;1.19 in central
# 	found com.sun.jersey#jersey-client;1.19 in central
# 	found javax.ws.rs#jsr311-api;1.1.1 in central
# 	found com.sun.jersey#jersey-client;1.19 in central
# 	found com.google.inject.extensions#guice-servlet;4.0 in central
# 	found com.google.inject.extensions#guice-servlet;4.0 in central	found com.google.inject#guice;4.0 in central
#
# 	found com.google.inject#guice;4.0 in central
# 	found javax.inject#javax.inject;1 in central
# 	found javax.inject#javax.inject;1 in central
# 	found aopalliance#aopalliance;1.0 in central
# 	found aopalliance#aopalliance;1.0 in central
# 	found com.google.guava#guava;27.0-jre in central
# 	found com.google.guava#guava;27.0-jre in central
# 	found com.google.guava#failureaccess;1.0 in central
# 	found com.google.guava#failureaccess;1.0 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;2.5.2 in central
# 	found org.checkerframework#checker-qual;2.5.2 in central
# 	found com.google.errorprone#error_prone_annotations;2.2.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.2.0 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.17 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.17 in central
# 	found com.sun.jersey#jersey-server;1.19 in central
# 	found com.sun.jersey#jersey-server;1.19 in central
# 	found com.sun.jersey#jersey-json;1.19 in central
# 	found com.sun.jersey#jersey-json;1.19 in central
# 	found org.codehaus.jettison#jettison;1.1 in central
# 	found com.sun.xml.bind#jaxb-impl;2.2.3-1 in central
# 	found org.codehaus.jettison#jettison;1.1 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in central
# 	found com.sun.xml.bind#jaxb-impl;2.2.3-1 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in central
# 	found org.codehaus.jackson#jackson-mapper-asl;1.9.13 in user-list
# 	found org.codehaus.jackson#jackson-mapper-asl;1.9.13 in user-list
# 	found org.codehaus.jackson#jackson-jaxrs;1.9.13 in central
# 	found org.codehaus.jackson#jackson-jaxrs;1.9.13 in central
# 	found org.codehaus.jackson#jackson-xc;1.9.13 in user-list
# 	found org.codehaus.jackson#jackson-xc;1.9.13 in user-list
# 	found com.sun.jersey.contribs#jersey-guice;1.19 in user-list
# 	found com.sun.jersey.contribs#jersey-guice;1.19 in user-list
# 	found com.sun.jersey#jersey-servlet;1.19 in central
# 	found com.sun.jersey#jersey-servlet;1.19 in central
# 	found com.fasterxml.jackson.module#jackson-module-jaxb-annotations;2.13.0 in central
# 	found com.fasterxml.jackson.module#jackson-module-jaxb-annotations;2.13.0 in central
# 	found jakarta.xml.bind#jakarta.xml.bind-api;2.3.3 in central
# 	found jakarta.xml.bind#jakarta.xml.bind-api;2.3.3 in central
# 	found jakarta.activation#jakarta.activation-api;1.2.1 in central
# 	found jakarta.activation#jakarta.activation-api;1.2.1 in central
# 	found com.fasterxml.jackson.jaxrs#jackson-jaxrs-json-provider;2.13.0 in central
# 	found com.fasterxml.jackson.jaxrs#jackson-jaxrs-json-provider;2.13.0 in central
# 	found com.fasterxml.jackson.jaxrs#jackson-jaxrs-base;2.13.0 in central
# 	found com.fasterxml.jackson.jaxrs#jackson-jaxrs-base;2.13.0 in central
# 	found org.slf4j#slf4j-log4j12;1.7.30 in central
# 	found org.slf4j#slf4j-log4j12;1.7.30 in central
# 	found org.jline#jline;3.9.0 in central
# 	found org.jline#jline;3.9.0 in central
# 	found io.netty#netty;3.10.6.Final in central
# 	found io.netty#netty;3.10.6.Final in central
# 	found org.apache.hadoop#hadoop-common;3.3.2 in central
# 	found org.apache.hadoop#hadoop-common;3.3.2 in central
# 	found org.apache.commons#commons-math3;3.1.1 in central
# 	found org.apache.commons#commons-math3;3.1.1 in central
# 	found commons-net#commons-net;3.6 in central
# 	found commons-collections#commons-collections;3.2.2 in central
# 	found commons-net#commons-net;3.6 in central
# 	found org.eclipse.jetty#jetty-server;9.4.43.v20210629 in central
# 	found commons-collections#commons-collections;3.2.2 in central
# 	found org.eclipse.jetty#jetty-server;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-servlet;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-security;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-servlet;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-webapp;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-security;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-xml;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 in central
# 	found commons-beanutils#commons-beanutils;1.9.4 in central
# 	found org.eclipse.jetty#jetty-webapp;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-xml;9.4.43.v20210629 in central
# 	found org.apache.commons#commons-configuration2;2.1.1 in central
# 	found org.apache.commons#commons-lang3;3.12.0 in central
# 	found org.apache.commons#commons-text;1.4 in central
# 	found commons-beanutils#commons-beanutils;1.9.4 in central
# 	found com.google.re2j#re2j;1.1 in central
# 	found org.apache.commons#commons-configuration2;2.1.1 in central
# 	found com.google.code.gson#gson;2.8.9 in central
# 	found org.apache.commons#commons-lang3;3.12.0 in central
# 	found com.jcraft#jsch;0.1.55 in central
# 	found org.apache.commons#commons-text;1.4 in central
# 	found org.apache.curator#curator-recipes;4.2.0 in central
# 	found com.google.re2j#re2j;1.1 in central
# 	found com.google.code.gson#gson;2.8.9 in central
# 	found org.codehaus.woodstox#stax2-api;4.2.1 in central
# 	found com.fasterxml.woodstox#woodstox-core;5.3.0 in central
# 	found com.jcraft#jsch;0.1.55 in central
# 	found dnsjava#dnsjava;2.1.7 in central
# 	found org.apache.curator#curator-recipes;4.2.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.2 in central
# 	found org.codehaus.woodstox#stax2-api;4.2.1 in central
# 	found javax.servlet.jsp#jsp-api;2.1 in central
# 	found org.apache.avro#avro;1.8.2 in central
# 	found com.fasterxml.woodstox#woodstox-core;5.3.0 in central
# 	found com.thoughtworks.paranamer#paranamer;2.7 in central
# 	found dnsjava#dnsjava;2.1.7 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.2 in central
# 	found org.apache.xbean#xbean-asm6-shaded;4.10 in central
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.1.3 in central
# 	found javax.servlet.jsp#jsp-api;2.1 in central
# 	found org.apache.avro#avro;1.8.2 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.1.3 in central
# 	found com.thoughtworks.paranamer#paranamer;2.7 in central
# 	found org.apache.commons#commons-pool2;2.6.2 in central
# 	found org.apache.kafka#kafka-clients;3.1.0 in central
# 	found org.apache.xbean#xbean-asm6-shaded;4.10 in central
# 	found com.github.luben#zstd-jni;1.5.0-4 in central
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.1.3 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.4 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.1.3 in central
# 	found com.jasonclawson#jackson-dataformat-hocon;1.1.0 in central
# 	found org.apache.commons#commons-pool2;2.6.2 in central
# 	found com.redislabs#spark-redis_2.12;3.1.0 in central
# 	found org.apache.kafka#kafka-clients;3.1.0 in central
# 	found redis.clients#jedis;3.9.0 in central
# 	found com.github.luben#zstd-jni;1.5.0-4 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found com.google.protobuf#protobuf-java;3.19.4 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.4 in central
# 	found com.jasonclawson#jackson-dataformat-hocon;1.1.0 in central
# 	found com.redislabs#spark-redis_2.12;3.1.0 in central
# 	found io.minio#spark-select_2.11;2.1 in central
# 	found redis.clients#jedis;3.9.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# 	found com.google.protobuf#protobuf-java;3.19.4 in central
# 	found com.amazonaws#aws-java-sdk;1.11.434 in central
# 	found io.minio#spark-select_2.11;2.1 in central
# 	found com.amazonaws#aws-java-sdk;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-signer;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-signer;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-core;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-core;1.11.434 in central
# 	found software.amazon.ion#ion-java;1.0.2 in central
# 	found software.amazon.ion#ion-java;1.0.2 in central
# 	found com.fasterxml.jackson.dataformat#jackson-dataformat-cbor;2.6.7 in central	found com.fasterxml.jackson.dataformat#jackson-dataformat-cbor;2.6.7 in central
#
# 	found joda-time#joda-time;2.8.1 in central
# 	found com.amazonaws#jmespath-java;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-dlm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-macie;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-eks;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mediatailor;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-neptune;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-pi;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iot1clickprojects;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iot1clickdevices;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iotanalytics;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-acmpca;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-secretsmanager;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-fms;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-connect;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-transcribe;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-autoscalingplans;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-workmail;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-servicediscovery;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloud9;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-serverlessapplicationrepository;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-alexaforbusiness;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-resourcegroups;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-comprehend;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-translate;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-sagemaker;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iotjobsdataplane;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-sagemakerruntime;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-kinesisvideo;1.11.434 in central
# 	found io.netty#netty-codec-http;4.1.17.Final in central
# 	found io.netty#netty-codec;4.1.17.Final in central
# 	found io.netty#netty-transport;4.1.17.Final in central
# 	found io.netty#netty-buffer;4.1.17.Final in central
# 	found io.netty#netty-common;4.1.17.Final in central
# 	found io.netty#netty-resolver;4.1.17.Final in central
# 	found io.netty#netty-handler;4.1.17.Final in central
# 	found com.amazonaws#aws-java-sdk-appsync;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-guardduty;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mq;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mediaconvert;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mediastore;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mediastoredata;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-medialive;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mediapackage;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-costexplorer;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-pricing;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mobile;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudhsmv2;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-glue;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-migrationhub;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-dax;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-greengrass;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-athena;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-marketplaceentitlement;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-codestar;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-lexmodelbuilding;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-resourcegroupstaggingapi;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-pinpoint;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-xray;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-opsworkscm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-support;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-simpledb;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-servicecatalog;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-servermigration;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-simpleworkflow;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-storagegateway;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-route53;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-s3;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-kms;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-importexport;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-sts;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-sqs;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-rds;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-redshift;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elasticbeanstalk;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-glacier;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-sns;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iam;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-datapipeline;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elasticloadbalancing;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elasticloadbalancingv2;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-emr;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elasticache;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elastictranscoder;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-ec2;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-dynamodb;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-budgets;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudtrail;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudwatch;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-logs;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-events;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cognitoidentity;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cognitosync;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-directconnect;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudformation;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudfront;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-clouddirectory;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-kinesis;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-opsworks;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-ses;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-autoscaling;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudsearch;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudwatchmetrics;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-codedeploy;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-codepipeline;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-config;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-lambda;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-ecs;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-ecr;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudhsm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-ssm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-workspaces;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-machinelearning;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-directory;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-efs;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-codecommit;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-devicefarm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elasticsearch;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-waf;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-marketplacecommerceanalytics;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-inspector;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iot;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-api-gateway;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-acm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-gamelift;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-dms;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-marketplacemeteringservice;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cognitoidp;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-discovery;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-applicationautoscaling;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-snowball;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-rekognition;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-polly;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-lightsail;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-stepfunctions;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-health;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-costandusagereport;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-codebuild;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-appstream;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-shield;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-batch;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-lex;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mechanicalturkrequester;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-organizations;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-workdocs;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-models;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-swf-libraries;1.11.22 in central
# 	found org.apache.commons#commons-csv;1.1 in central
# 	found org.mockito#mockito-core;2.0.31-beta in central
# 	found net.bytebuddy#byte-buddy;0.6.14 in central
# 	found org.objenesis#objenesis;2.1 in central
# 	found org.apache.hadoop#hadoop-aws;3.3.2 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.11.1026 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# downloading https://repo1.maven.org/maven2/joda-time/joda-time/2.8.1/joda-time-2.8.1.jar ...
# 	[SUCCESSFUL ] joda-time#joda-time;2.8.1!joda-time.jar (1388ms)
# :: resolution report :: resolve 6777ms :: artifacts dl 1445ms
# 	:: modules in use:
# 	aopalliance#aopalliance;1.0 from central in [default]
# 	com.amazonaws#aws-java-sdk;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-acm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-acmpca;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-alexaforbusiness;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-api-gateway;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-applicationautoscaling;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-appstream;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-appsync;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-athena;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-autoscaling;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-autoscalingplans;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-batch;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-budgets;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-bundle;1.11.1026 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloud9;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-clouddirectory;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudformation;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudfront;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudhsm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudhsmv2;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudsearch;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudtrail;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudwatch;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudwatchmetrics;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-codebuild;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-codecommit;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-codedeploy;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-codepipeline;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-codestar;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cognitoidentity;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cognitoidp;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cognitosync;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-comprehend;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-config;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-connect;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-core;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-costandusagereport;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-costexplorer;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-datapipeline;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-dax;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-devicefarm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-directconnect;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-directory;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-discovery;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-dlm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-dms;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-dynamodb;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ec2;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ecr;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ecs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-efs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-eks;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elasticache;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elasticbeanstalk;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elasticloadbalancing;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elasticloadbalancingv2;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elasticsearch;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elastictranscoder;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-emr;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-events;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-fms;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-gamelift;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-glacier;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-glue;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-greengrass;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-guardduty;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-health;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iam;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-importexport;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-inspector;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iot;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iot1clickdevices;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iot1clickprojects;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotanalytics;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotjobsdataplane;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-kinesis;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-kinesisvideo;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-kms;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-lambda;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-lex;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-lexmodelbuilding;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-lightsail;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-logs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-machinelearning;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-macie;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-marketplacecommerceanalytics;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-marketplaceentitlement;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-marketplacemeteringservice;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mechanicalturkrequester;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediaconvert;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-medialive;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediapackage;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediastore;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediastoredata;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediatailor;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-migrationhub;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mobile;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-models;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mq;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-neptune;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-opsworks;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-opsworkscm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-organizations;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-pi;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-pinpoint;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-polly;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-pricing;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-rds;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-redshift;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-rekognition;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-resourcegroups;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-resourcegroupstaggingapi;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-route53;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-s3;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sagemaker;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sagemakerruntime;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-secretsmanager;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-serverlessapplicationrepository;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-servermigration;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-servicecatalog;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-servicediscovery;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ses;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-shield;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-signer;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-simpledb;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-simpleworkflow;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-snowball;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sns;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sqs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ssm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-stepfunctions;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-storagegateway;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sts;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-support;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-swf-libraries;1.11.22 from central in [default]
# 	com.amazonaws#aws-java-sdk-transcribe;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-translate;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-waf;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-workdocs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-workmail;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-workspaces;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-xray;1.11.434 from central in [default]
# 	com.amazonaws#jmespath-java;1.11.434 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.13.0 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.13.0 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.13.0 from central in [default]
# 	com.fasterxml.jackson.dataformat#jackson-dataformat-cbor;2.6.7 from central in [default]
# 	com.fasterxml.jackson.jaxrs#jackson-jaxrs-base;2.13.0 from central in [default]
# 	com.fasterxml.jackson.jaxrs#jackson-jaxrs-json-provider;2.13.0 from central in [default]
# 	com.fasterxml.jackson.module#jackson-module-jaxb-annotations;2.13.0 from central in [default]
# 	com.fasterxml.woodstox#woodstox-core;5.3.0 from central in [default]
# 	com.github.luben#zstd-jni;1.5.0-4 from central in [default]
# 	com.github.stephenc.jcip#jcip-annotations;1.0-1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.8.9 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.2.0 from central in [default]
# 	com.google.guava#failureaccess;1.0 from central in [default]
# 	com.google.guava#guava;27.0-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.inject#guice;4.0 from central in [default]
# 	com.google.inject.extensions#guice-servlet;4.0 from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.google.protobuf#protobuf-java;3.19.4 from central in [default]
# 	com.google.re2j#re2j;1.1 from central in [default]
# 	com.jasonclawson#jackson-dataformat-hocon;1.1.0 from central in [default]
# 	com.jcraft#jsch;0.1.55 from central in [default]
# 	com.nimbusds#nimbus-jose-jwt;9.8.1 from central in [default]
# 	com.redislabs#spark-redis_2.12;3.1.0 from central in [default]
# 	com.squareup.okhttp#okhttp;2.7.5 from central in [default]
# 	com.squareup.okio#okio;1.6.0 from central in [default]
# 	com.sun.jersey#jersey-client;1.19 from central in [default]
# 	com.sun.jersey#jersey-core;1.19 from central in [default]
# 	com.sun.jersey#jersey-json;1.19 from central in [default]
# 	com.sun.jersey#jersey-server;1.19 from central in [default]
# 	com.sun.jersey#jersey-servlet;1.19 from central in [default]
# 	com.sun.jersey.contribs#jersey-guice;1.19 from user-list in [default]
# 	com.sun.xml.bind#jaxb-impl;2.2.3-1 from central in [default]
# 	com.thoughtworks.paranamer#paranamer;2.7 from central in [default]
# 	com.typesafe#config;1.3.4 from central in [default]
# 	commons-beanutils#commons-beanutils;1.9.4 from central in [default]
# 	commons-cli#commons-cli;1.2 from central in [default]
# 	commons-codec#commons-codec;1.11 from central in [default]
# 	commons-collections#commons-collections;3.2.2 from central in [default]
# 	commons-io#commons-io;2.8.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	commons-net#commons-net;3.6 from central in [default]
# 	dnsjava#dnsjava;2.1.7 from central in [default]
# 	io.minio#spark-select_2.11;2.1 from central in [default]
# 	io.netty#netty;3.10.6.Final from central in [default]
# 	io.netty#netty-buffer;4.1.17.Final from central in [default]
# 	io.netty#netty-codec;4.1.17.Final from central in [default]
# 	io.netty#netty-codec-http;4.1.17.Final from central in [default]
# 	io.netty#netty-common;4.1.17.Final from central in [default]
# 	io.netty#netty-handler;4.1.17.Final from central in [default]
# 	io.netty#netty-resolver;4.1.17.Final from central in [default]
# 	io.netty#netty-transport;4.1.17.Final from central in [default]
# 	jakarta.activation#jakarta.activation-api;1.2.1 from central in [default]
# 	jakarta.xml.bind#jakarta.xml.bind-api;2.3.3 from central in [default]
# 	javax.inject#javax.inject;1 from central in [default]
# 	javax.servlet#javax.servlet-api;3.1.0 from central in [default]
# 	javax.servlet.jsp#jsp-api;2.1 from central in [default]
# 	javax.ws.rs#javax.ws.rs-api;2.1.1 from central in [default]
# 	javax.ws.rs#jsr311-api;1.1.1 from central in [default]
# 	javax.xml.bind#jaxb-api;2.2.11 from central in [default]
# ...
# 	com.amazonaws#aws-java-sdk-neptune;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-opsworks;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-opsworkscm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-organizations;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-pi;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-pinpoint;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-polly;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-pricing;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-rds;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-redshift;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-rekognition;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-resourcegroups;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-resourcegroupstaggingapi;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-route53;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-s3;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sagemaker;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sagemakerruntime;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-secretsmanager;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-serverlessapplicationrepository;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-servermigration;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-servicecatalog;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-servicediscovery;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ses;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-shield;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-signer;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-simpledb;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-simpleworkflow;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-snowball;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sns;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sqs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ssm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-stepfunctions;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-storagegateway;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sts;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-support;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-swf-libraries;1.11.22 from central in [default]
# 	com.amazonaws#aws-java-sdk-transcribe;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-translate;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-waf;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-workdocs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-workmail;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-workspaces;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-xray;1.11.434 from central in [default]
# 	com.amazonaws#jmespath-java;1.11.434 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.13.0 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.13.0 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.13.0 from central in [default]
# 	com.fasterxml.jackson.dataformat#jackson-dataformat-cbor;2.6.7 from central in [default]
# 	com.fasterxml.jackson.jaxrs#jackson-jaxrs-base;2.13.0 from central in [default]
# 	com.fasterxml.jackson.jaxrs#jackson-jaxrs-json-provider;2.13.0 from central in [default]
# 	com.fasterxml.jackson.module#jackson-module-jaxb-annotations;2.13.0 from central in [default]
# 	com.fasterxml.woodstox#woodstox-core;5.3.0 from central in [default]
# 	com.github.luben#zstd-jni;1.5.0-4 from central in [default]
# 	com.github.stephenc.jcip#jcip-annotations;1.0-1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.8.9 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.2.0 from central in [default]
# 	com.google.guava#failureaccess;1.0 from central in [default]
# 	com.google.guava#guava;27.0-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.inject#guice;4.0 from central in [default]
# 	com.google.inject.extensions#guice-servlet;4.0 from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.google.protobuf#protobuf-java;3.19.4 from central in [default]
# 	com.google.re2j#re2j;1.1 from central in [default]
# 	com.jasonclawson#jackson-dataformat-hocon;1.1.0 from central in [default]
# 	com.jcraft#jsch;0.1.55 from central in [default]
# 	com.nimbusds#nimbus-jose-jwt;9.8.1 from central in [default]
# 	com.redislabs#spark-redis_2.12;3.1.0 from central in [default]
# 	com.squareup.okhttp#okhttp;2.7.5 from central in [default]
# 	com.squareup.okio#okio;1.6.0 from central in [default]
# 	com.sun.jersey#jersey-client;1.19 from central in [default]
# 	com.sun.jersey#jersey-core;1.19 from central in [default]
# 	com.sun.jersey#jersey-json;1.19 from central in [default]
# 	com.sun.jersey#jersey-server;1.19 from central in [default]
# 	com.sun.jersey#jersey-servlet;1.19 from central in [default]
# 	com.sun.jersey.contribs#jersey-guice;1.19 from user-list in [default]
# 	com.sun.xml.bind#jaxb-impl;2.2.3-1 from central in [default]
# 	com.thoughtworks.paranamer#paranamer;2.7 from central in [default]
# 	com.typesafe#config;1.3.4 from central in [default]
# 	commons-beanutils#commons-beanutils;1.9.4 from central in [default]
# 	commons-cli#commons-cli;1.2 from central in [default]
# 	commons-codec#commons-codec;1.11 from central in [default]
# 	commons-collections#commons-collections;3.2.2 from central in [default]
# 	commons-io#commons-io;2.8.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	commons-net#commons-net;3.6 from central in [default]
# 	dnsjava#dnsjava;2.1.7 from central in [default]
# 	io.minio#spark-select_2.11;2.1 from central in [default]
# 	io.netty#netty;3.10.6.Final from central in [default]
# 	io.netty#netty-buffer;4.1.17.Final from central in [default]
# 	io.netty#netty-codec;4.1.17.Final from central in [default]
# 	io.netty#netty-codec-http;4.1.17.Final from central in [default]
# 	io.netty#netty-common;4.1.17.Final from central in [default]
# 	io.netty#netty-handler;4.1.17.Final from central in [default]
# 	io.netty#netty-resolver;4.1.17.Final from central in [default]
# 	io.netty#netty-transport;4.1.17.Final from central in [default]
# 	jakarta.activation#jakarta.activation-api;1.2.1 from central in [default]
# 	jakarta.xml.bind#jakarta.xml.bind-api;2.3.3 from central in [default]
# 	javax.inject#javax.inject;1 from central in [default]
# 	javax.servlet#javax.servlet-api;3.1.0 from central in [default]
# 	javax.servlet.jsp#jsp-api;2.1 from central in [default]
# 	javax.ws.rs#javax.ws.rs-api;2.1.1 from central in [default]
# 	javax.ws.rs#jsr311-api;1.1.1 from central in [default]
# 	javax.xml.bind#jaxb-api;2.2.11 from central in [default]
# 	joda-time#joda-time;2.8.1 from central in [default]
# 	log4j#log4j;1.2.17 from central in [default]
# 	net.bytebuddy#byte-buddy;0.6.14 from central in [default]
# 	net.minidev#accessors-smart;2.4.7 from central in [default]
# 	net.minidev#json-smart;2.4.7 from central in [default]
# 	org.apache.avro#avro;1.8.2 from central in [default]
# 	org.apache.commons#commons-compress;1.21 from central in [default]
# 	org.apache.commons#commons-configuration2;2.1.1 from central in [default]
# 	org.apache.commons#commons-csv;1.1 from central in [default]
# 	org.apache.commons#commons-lang3;3.12.0 from central in [default]
# 	org.apache.commons#commons-math3;3.1.1 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.commons#commons-text;1.4 from central in [default]
# 	org.apache.curator#curator-client;4.2.0 from central in [default]
# 	org.apache.curator#curator-framework;4.2.0 from central in [default]
# 	org.apache.curator#curator-recipes;4.2.0 from central in [default]
# 	org.apache.hadoop#hadoop-annotations;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-auth;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-common;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-hdfs-client;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-mapreduce-client-core;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-api;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-client;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-common;3.3.2 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_7;1.1.1 from central in [default]
# 	org.apache.httpcomponents#httpclient;4.5.13 from central in [default]
# 	org.apache.httpcomponents#httpcore;4.4.13 from central in [default]
# 	org.apache.kafka#kafka-clients;3.1.0 from central in [default]
# 	org.apache.kerby#kerb-admin;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-client;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-common;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-core;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-crypto;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-identity;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-server;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-simplekdc;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-util;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-asn1;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-config;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-pkix;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-util;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-xdr;1.0.1 from central in [default]
# 	org.apache.kerby#token-provider;1.0.1 from central in [default]
# 	org.apache.logging.log4j#log4j-core;2.17.2 from central in [default]
# 	org.apache.spark#spark-avro_2.12;3.3.0 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.1.3 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.1.3 from central in [default]
# 	org.apache.xbean#xbean-asm6-shaded;4.10 from central in [default]
# 	org.apache.yetus#audience-annotations;0.5.0 from central in [default]
# 	org.apache.zookeeper#zookeeper;3.5.6 from central in [default]
# 	org.apache.zookeeper#zookeeper-jute;3.5.6 from central in [default]
# 	org.checkerframework#checker-qual;2.5.2 from central in [default]
# 	org.codehaus.jackson#jackson-core-asl;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-jaxrs;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-mapper-asl;1.9.13 from user-list in [default]
# 	org.codehaus.jackson#jackson-xc;1.9.13 from user-list in [default]
# 	org.codehaus.jettison#jettison;1.1 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.17 from central in [default]
# 	org.codehaus.woodstox#stax2-api;4.2.1 from central in [default]
# 	org.eclipse.jetty#jetty-client;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-http;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-io;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-security;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-server;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-servlet;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-util;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-webapp;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-xml;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-api;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-client;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-common;9.4.43.v20210629 from central in [default]
# 	org.jline#jline;3.9.0 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.mockito#mockito-core;2.0.31-beta from central in [default]
# 	org.objenesis#objenesis;2.1 from central in [default]
# 	org.ow2.asm#asm;5.0.4 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from central in [default]
# 	org.slf4j#slf4j-log4j12;1.7.30 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.tukaani#xz;1.8 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.8.4 from central in [default]
# 	redis.clients#jedis;3.9.0 from central in [default]
# 	software.amazon.ion#ion-java;1.0.2 from central in [default]
# 	:: evicted modules:
# 	com.google.protobuf#protobuf-java;2.5.0 by [com.google.protobuf#protobuf-java;3.19.4] in [default]
# 	org.apache.avro#avro;1.7.7 by [org.apache.avro#avro;1.8.2] in [default]
# 	org.xerial.snappy#snappy-java;1.1.8.2 by [org.xerial.snappy#snappy-java;1.1.8.4] in [default]
# 	org.xerial.snappy#snappy-java;1.1.1.3 by [org.xerial.snappy#snappy-java;1.1.8.2] in [default]
# 	org.apache.commons#commons-compress;1.8.1 by [org.apache.commons#commons-compress;1.21] in [default]
# 	org.tukaani#xz;1.5 by [org.tukaani#xz;1.8] in [default]
# 	org.slf4j#slf4j-api;1.7.7 by [org.slf4j#slf4j-api;1.7.30] in [default]
# 	org.apache.kafka#kafka-clients;2.6.0 by [org.apache.kafka#kafka-clients;3.1.0] in [default]
# 	org.apache.commons#commons-pool2;2.6.2 by [org.apache.commons#commons-pool2;2.11.1] in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.4.1.1 by [com.fasterxml.jackson.core#jackson-core;2.13.0] in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.4.1 by [com.fasterxml.jackson.core#jackson-annotations;2.13.0] in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.4.1.1 by [com.fasterxml.jackson.core#jackson-databind;2.13.0] in [default]
# 	com.typesafe#config;1.2.1 by [com.typesafe#config;1.3.4] in [default]
# 	commons-io#commons-io;2.6 by [commons-io#commons-io;2.8.0] in [default]
# 	org.apache.httpcomponents#httpclient;4.5.5 by [org.apache.httpcomponents#httpclient;4.5.13] in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.6.7 by [com.fasterxml.jackson.core#jackson-core;2.13.0] in [default]
# 	com.amazonaws#aws-java-sdk-simpleworkflow;1.11.22 by [com.amazonaws#aws-java-sdk-simpleworkflow;1.11.434] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |  309  |   1   |   0   |   17  ||  292  |   0   |
# 	---------------------------------------------------------------------
#
# :: problems summary ::
# :::: WARNINGS
# 	problem while downloading module descriptor: https://repo1.maven.org/maven2/joda-time/joda-time/2.8.1/joda-time-2.8.1.pom: Downloaded file size (0) doesn't match expected Content Length (28722) for https://repo1.maven.org/maven2/joda-time/joda-time/2.8.1/joda-time-2.8.1.pom. Please retry. (350ms)
#
#
# :: USE VERBOSE OR DEBUG MESSAGE LEVEL FOR MORE DETAILS
# :: retrieving :: org.apache.spark#spark-submit-parent-78004ccf-8601-42d9-967b-472eca5ca85f
# 	confs: [default]
# 	0 artifacts copied, 292 already retrieved (0kB/33ms)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>x
# 2024-09-06 16:52:06.496 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:198 - Pyspark job Completed
# >
# 2024-09-06 16:52:07.501 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:234 - Spark job with pid 122423 finished in: 98 seconds.
# >

# %%
# If the notebook is runnong on Jupyter, start a spark session:
if is_jupyter():
    spark = (
        SparkSession
        .builder
        .appName("feathr")
        .config("spark.jars.packages", "org.apache.hadoop:hadoop-common:3.3.2,org.apache.hadoop:hadoop-mapreduce-client-core:3.3.2,org.apache.hadoop:hadoop-aws:3.3.2,io.minio:spark-select_2.11:2.1")
        .config("fs.s3a.endpoint", "http://127.0.0.1:9000")
        .config("fs.s3a.access.key", os.getenv('S3_ACCESS_KEY'))
        .config("fs.s3a.secret.key", os.getenv('S3_SECRET_KEY'))
        .config("fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
        .config("fs.s3a.path.style.access", "true")
        .config("fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider")
        .config("spark.ui.port", "8080")  # Set ui port other than the default one (4040) so that feathr spark job doesn't fail. 
        .getOrCreate()
    )

# Else, you must already have a spark session object available in databricks or synapse notebooks.
# Out:
# bash: /mnt/e/setup/miniconda3/lib/libtinfo.so.6: no version information available (required by bash)
# bash: /mnt/e/setup/miniconda3/lib/libtinfo.so.6: no version information available (required by bash)
# Warning: Ignoring non-Spark config property: fs.s3a.endpoint
# Warning: Ignoring non-Spark config property: fs.s3a.impl
# Warning: Ignoring non-Spark config property: fs.s3a.access.key
# Warning: Ignoring non-Spark config property: fs.s3a.path.style.access
# Warning: Ignoring non-Spark config property: fs.s3a.aws.credentials.provider
# Warning: Ignoring non-Spark config property: fs.s3a.secret.key
# :: loading settings :: url = jar:file:/mnt/e/setup/miniconda3/envs/feathr3.9/lib/python3.9/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/cuong/.ivy2/cache
# The jars for the packages stored in: /home/cuong/.ivy2/jars
# org.apache.hadoop#hadoop-common added as a dependency
# org.apache.hadoop#hadoop-mapreduce-client-core added as a dependency
# org.apache.hadoop#hadoop-aws added as a dependency
# io.minio#spark-select_2.11 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-752fd5bf-6faf-4c0e-b792-1e2c155f8cc9;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-common;3.3.2 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_7;1.1.1 in central
# 	found org.apache.hadoop#hadoop-annotations;3.3.2 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 in central
# 	found com.google.guava#guava;27.0-jre in central
# 	found com.google.guava#failureaccess;1.0 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;2.5.2 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.17 in central
# 	found commons-cli#commons-cli;1.2 in central
# 	found org.apache.commons#commons-math3;3.1.1 in central
# 	found org.apache.httpcomponents#httpclient;4.5.13 in central
# 	found org.apache.httpcomponents#httpcore;4.4.13 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found commons-codec#commons-codec;1.11 in central
# 	found commons-io#commons-io;2.8.0 in central
# 	found commons-net#commons-net;3.6 in central
# 	found commons-collections#commons-collections;3.2.2 in central
# 	found javax.servlet#javax.servlet-api;3.1.0 in central
# 	found org.eclipse.jetty#jetty-server;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-http;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-io;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-servlet;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-security;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-webapp;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-xml;9.4.43.v20210629 in central
# 	found com.sun.jersey#jersey-core;1.19 in central
# 	found javax.ws.rs#jsr311-api;1.1.1 in central
# 	found com.sun.jersey#jersey-servlet;1.19 in central
# 	found com.sun.jersey#jersey-server;1.19 in central
# 	found com.sun.jersey#jersey-json;1.19 in central
# 	found org.codehaus.jettison#jettison;1.1 in central
# 	found com.sun.xml.bind#jaxb-impl;2.2.3-1 in central
# 	found javax.xml.bind#jaxb-api;2.2.11 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in central
# 	found org.codehaus.jackson#jackson-mapper-asl;1.9.13 in spark-list
# 	found org.codehaus.jackson#jackson-jaxrs;1.9.13 in central
# 	found org.codehaus.jackson#jackson-xc;1.9.13 in spark-list
# 	found log4j#log4j;1.2.17 in central
# 	found commons-beanutils#commons-beanutils;1.9.4 in central
# 	found org.apache.commons#commons-configuration2;2.1.1 in central
# 	found org.apache.commons#commons-lang3;3.12.0 in central
# 	found org.apache.commons#commons-text;1.4 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.slf4j#slf4j-log4j12;1.7.30 in central
# 	found org.apache.avro#avro;1.7.7 in central
# 	found com.thoughtworks.paranamer#paranamer;2.3 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.2 in central
# 	found org.apache.commons#commons-compress;1.21 in central
# 	found com.google.re2j#re2j;1.1 in central
# 	found com.google.protobuf#protobuf-java;2.5.0 in central
# 	found com.google.code.gson#gson;2.8.9 in central
# 	found org.apache.hadoop#hadoop-auth;3.3.2 in central
# 	found com.nimbusds#nimbus-jose-jwt;9.8.1 in central
# 	found com.github.stephenc.jcip#jcip-annotations;1.0-1 in central
# 	found net.minidev#json-smart;2.4.7 in central
# 	found net.minidev#accessors-smart;2.4.7 in central
# 	found org.ow2.asm#asm;5.0.4 in central
# 	found org.apache.zookeeper#zookeeper;3.5.6 in central
# 	found org.apache.zookeeper#zookeeper-jute;3.5.6 in central
# 	found org.apache.yetus#audience-annotations;0.5.0 in central
# 	found org.apache.curator#curator-framework;4.2.0 in central
# 	found org.apache.curator#curator-client;4.2.0 in central
# 	found org.apache.kerby#kerb-simplekdc;1.0.1 in central
# 	found org.apache.kerby#kerb-client;1.0.1 in central
# 	found org.apache.kerby#kerby-config;1.0.1 in central
# 	found org.apache.kerby#kerb-core;1.0.1 in central
# 	found org.apache.kerby#kerby-pkix;1.0.1 in central
# 	found org.apache.kerby#kerby-asn1;1.0.1 in central
# 	found org.apache.kerby#kerby-util;1.0.1 in central
# 	found org.apache.kerby#kerb-common;1.0.1 in central
# 	found org.apache.kerby#kerb-crypto;1.0.1 in spark-list
# 	found org.apache.kerby#kerb-util;1.0.1 in central
# 	found org.apache.kerby#token-provider;1.0.1 in central
# 	found org.apache.kerby#kerb-admin;1.0.1 in central
# 	found org.apache.kerby#kerb-server;1.0.1 in central
# 	found org.apache.kerby#kerb-identity;1.0.1 in central
# 	found org.apache.kerby#kerby-xdr;1.0.1 in central
# 	found com.jcraft#jsch;0.1.55 in central
# 	found org.apache.curator#curator-recipes;4.2.0 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.13.0 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.13.0 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.13.0 in central
# 	found org.codehaus.woodstox#stax2-api;4.2.1 in central
# 	found com.fasterxml.woodstox#woodstox-core;5.3.0 in central
# 	found dnsjava#dnsjava;2.1.7 in central
# 	found jakarta.activation#jakarta.activation-api;1.2.1 in central
# 	found javax.servlet.jsp#jsp-api;2.1 in central
# 	found org.apache.hadoop#hadoop-mapreduce-client-core;3.3.2 in central
# 	found org.apache.hadoop#hadoop-yarn-client;3.3.2 in central
# 	found org.eclipse.jetty.websocket#websocket-client;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-client;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-common;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-api;9.4.43.v20210629 in central
# 	found org.apache.hadoop#hadoop-yarn-api;3.3.2 in central
# 	found javax.ws.rs#javax.ws.rs-api;2.1.1 in central
# 	found org.apache.hadoop#hadoop-yarn-common;3.3.2 in central
# 	found org.apache.hadoop#hadoop-hdfs-client;3.3.2 in central
# 	found com.squareup.okhttp#okhttp;2.7.5 in central
# 	found com.squareup.okio#okio;1.6.0 in central
# 	found com.sun.jersey#jersey-client;1.19 in central
# 	found com.google.inject.extensions#guice-servlet;4.0 in central
# 	found com.google.inject#guice;4.0 in central
# 	found javax.inject#javax.inject;1 in central
# 	found aopalliance#aopalliance;1.0 in central
# 	found com.sun.jersey.contribs#jersey-guice;1.19 in spark-list
# 	found com.fasterxml.jackson.module#jackson-module-jaxb-annotations;2.13.0 in central
# 	found jakarta.xml.bind#jakarta.xml.bind-api;2.3.3 in central
# 	found com.fasterxml.jackson.jaxrs#jackson-jaxrs-json-provider;2.13.0 in central
# 	found com.fasterxml.jackson.jaxrs#jackson-jaxrs-base;2.13.0 in central
# 	found org.jline#jline;3.9.0 in central
# 	found io.netty#netty;3.10.6.Final in central
# 	found org.apache.hadoop#hadoop-aws;3.3.2 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.11.1026 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# 	found io.minio#spark-select_2.11;2.1 in central
# 	found com.amazonaws#aws-java-sdk;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-signer;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-core;1.11.434 in central
# 	found software.amazon.ion#ion-java;1.0.2 in central
# 	found com.fasterxml.jackson.dataformat#jackson-dataformat-cbor;2.6.7 in central
# 	found joda-time#joda-time;2.8.1 in central
# 	found com.amazonaws#jmespath-java;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-dlm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-macie;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-eks;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mediatailor;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-neptune;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-pi;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iot1clickprojects;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iot1clickdevices;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iotanalytics;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-acmpca;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-secretsmanager;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-fms;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-connect;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-transcribe;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-autoscalingplans;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-workmail;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-servicediscovery;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloud9;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-serverlessapplicationrepository;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-alexaforbusiness;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-resourcegroups;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-comprehend;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-translate;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-sagemaker;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iotjobsdataplane;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-sagemakerruntime;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-kinesisvideo;1.11.434 in central
# 	found io.netty#netty-codec-http;4.1.17.Final in central
# 	found io.netty#netty-codec;4.1.17.Final in central
# 	found io.netty#netty-transport;4.1.17.Final in central
# 	found io.netty#netty-buffer;4.1.17.Final in central
# 	found io.netty#netty-common;4.1.17.Final in central
# 	found io.netty#netty-resolver;4.1.17.Final in central
# 	found io.netty#netty-handler;4.1.17.Final in central
# 	found com.amazonaws#aws-java-sdk-appsync;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-guardduty;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mq;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mediaconvert;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mediastore;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mediastoredata;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-medialive;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mediapackage;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-costexplorer;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-pricing;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mobile;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudhsmv2;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-glue;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-migrationhub;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-dax;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-greengrass;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-athena;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-marketplaceentitlement;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-codestar;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-lexmodelbuilding;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-resourcegroupstaggingapi;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-pinpoint;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-xray;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-opsworkscm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-support;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-simpledb;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-servicecatalog;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-servermigration;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-simpleworkflow;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-storagegateway;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-route53;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-s3;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-kms;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-importexport;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-sts;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-sqs;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-rds;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-redshift;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elasticbeanstalk;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-glacier;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-sns;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iam;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-datapipeline;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elasticloadbalancing;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elasticloadbalancingv2;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-emr;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elasticache;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elastictranscoder;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-ec2;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-dynamodb;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-budgets;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudtrail;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudwatch;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-logs;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-events;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cognitoidentity;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cognitosync;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-directconnect;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudformation;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudfront;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-clouddirectory;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-kinesis;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-opsworks;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-ses;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-autoscaling;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudsearch;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudwatchmetrics;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-codedeploy;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-codepipeline;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-config;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-lambda;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-ecs;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-ecr;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cloudhsm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-ssm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-workspaces;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-machinelearning;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-directory;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-efs;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-codecommit;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-devicefarm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-elasticsearch;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-waf;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-marketplacecommerceanalytics;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-inspector;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-iot;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-api-gateway;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-acm;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-gamelift;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-dms;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-marketplacemeteringservice;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-cognitoidp;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-discovery;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-applicationautoscaling;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-snowball;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-rekognition;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-polly;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-lightsail;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-stepfunctions;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-health;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-costandusagereport;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-codebuild;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-appstream;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-shield;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-batch;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-lex;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-mechanicalturkrequester;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-organizations;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-workdocs;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-models;1.11.434 in central
# 	found com.amazonaws#aws-java-sdk-swf-libraries;1.11.22 in central
# 	found org.apache.commons#commons-csv;1.1 in central
# 	found org.mockito#mockito-core;2.0.31-beta in central
# 	found net.bytebuddy#byte-buddy;0.6.14 in central
# 	found org.objenesis#objenesis;2.1 in central
# :: resolution report :: resolve 2626ms :: artifacts dl 46ms
# 	:: modules in use:
# 	aopalliance#aopalliance;1.0 from central in [default]
# 	com.amazonaws#aws-java-sdk;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-acm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-acmpca;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-alexaforbusiness;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-api-gateway;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-applicationautoscaling;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-appstream;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-appsync;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-athena;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-autoscaling;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-autoscalingplans;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-batch;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-budgets;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-bundle;1.11.1026 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloud9;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-clouddirectory;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudformation;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudfront;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudhsm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudhsmv2;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudsearch;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudtrail;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudwatch;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cloudwatchmetrics;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-codebuild;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-codecommit;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-codedeploy;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-codepipeline;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-codestar;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cognitoidentity;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cognitoidp;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-cognitosync;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-comprehend;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-config;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-connect;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-core;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-costandusagereport;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-costexplorer;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-datapipeline;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-dax;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-devicefarm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-directconnect;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-directory;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-discovery;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-dlm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-dms;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-dynamodb;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ec2;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ecr;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ecs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-efs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-eks;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elasticache;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elasticbeanstalk;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elasticloadbalancing;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elasticloadbalancingv2;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elasticsearch;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-elastictranscoder;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-emr;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-events;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-fms;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-gamelift;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-glacier;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-glue;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-greengrass;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-guardduty;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-health;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iam;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-importexport;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-inspector;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iot;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iot1clickdevices;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iot1clickprojects;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotanalytics;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotjobsdataplane;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-kinesis;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-kinesisvideo;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-kms;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-lambda;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-lex;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-lexmodelbuilding;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-lightsail;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-logs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-machinelearning;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-macie;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-marketplacecommerceanalytics;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-marketplaceentitlement;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-marketplacemeteringservice;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mechanicalturkrequester;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediaconvert;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-medialive;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediapackage;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediastore;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediastoredata;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediatailor;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-migrationhub;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mobile;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-models;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-mq;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-neptune;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-opsworks;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-opsworkscm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-organizations;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-pi;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-pinpoint;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-polly;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-pricing;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-rds;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-redshift;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-rekognition;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-resourcegroups;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-resourcegroupstaggingapi;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-route53;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-s3;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sagemaker;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sagemakerruntime;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-secretsmanager;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-serverlessapplicationrepository;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-servermigration;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-servicecatalog;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-servicediscovery;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ses;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-shield;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-signer;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-simpledb;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-simpleworkflow;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-snowball;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sns;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sqs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-ssm;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-stepfunctions;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-storagegateway;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-sts;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-support;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-swf-libraries;1.11.22 from central in [default]
# 	com.amazonaws#aws-java-sdk-transcribe;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-translate;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-waf;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-workdocs;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-workmail;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-workspaces;1.11.434 from central in [default]
# 	com.amazonaws#aws-java-sdk-xray;1.11.434 from central in [default]
# 	com.amazonaws#jmespath-java;1.11.434 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.13.0 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.13.0 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.13.0 from central in [default]
# 	com.fasterxml.jackson.dataformat#jackson-dataformat-cbor;2.6.7 from central in [default]
# 	com.fasterxml.jackson.jaxrs#jackson-jaxrs-base;2.13.0 from central in [default]
# 	com.fasterxml.jackson.jaxrs#jackson-jaxrs-json-provider;2.13.0 from central in [default]
# 	com.fasterxml.jackson.module#jackson-module-jaxb-annotations;2.13.0 from central in [default]
# 	com.fasterxml.woodstox#woodstox-core;5.3.0 from central in [default]
# 	com.github.stephenc.jcip#jcip-annotations;1.0-1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.8.9 from central in [default]
# 	com.google.guava#failureaccess;1.0 from central in [default]
# 	com.google.guava#guava;27.0-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.inject#guice;4.0 from central in [default]
# 	com.google.inject.extensions#guice-servlet;4.0 from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.google.protobuf#protobuf-java;2.5.0 from central in [default]
# 	com.google.re2j#re2j;1.1 from central in [default]
# 	com.jcraft#jsch;0.1.55 from central in [default]
# 	com.nimbusds#nimbus-jose-jwt;9.8.1 from central in [default]
# 	com.squareup.okhttp#okhttp;2.7.5 from central in [default]
# 	com.squareup.okio#okio;1.6.0 from central in [default]
# 	com.sun.jersey#jersey-client;1.19 from central in [default]
# 	com.sun.jersey#jersey-core;1.19 from central in [default]
# 	com.sun.jersey#jersey-json;1.19 from central in [default]
# 	com.sun.jersey#jersey-server;1.19 from central in [default]
# 	com.sun.jersey#jersey-servlet;1.19 from central in [default]
# 	com.sun.jersey.contribs#jersey-guice;1.19 from spark-list in [default]
# 	com.sun.xml.bind#jaxb-impl;2.2.3-1 from central in [default]
# 	com.thoughtworks.paranamer#paranamer;2.3 from central in [default]
# 	commons-beanutils#commons-beanutils;1.9.4 from central in [default]
# 	commons-cli#commons-cli;1.2 from central in [default]
# 	commons-codec#commons-codec;1.11 from central in [default]
# 	commons-collections#commons-collections;3.2.2 from central in [default]
# 	commons-io#commons-io;2.8.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	commons-net#commons-net;3.6 from central in [default]
# 	dnsjava#dnsjava;2.1.7 from central in [default]
# 	io.minio#spark-select_2.11;2.1 from central in [default]
# 	io.netty#netty;3.10.6.Final from central in [default]
# 	io.netty#netty-buffer;4.1.17.Final from central in [default]
# 	io.netty#netty-codec;4.1.17.Final from central in [default]
# 	io.netty#netty-codec-http;4.1.17.Final from central in [default]
# 	io.netty#netty-common;4.1.17.Final from central in [default]
# 	io.netty#netty-handler;4.1.17.Final from central in [default]
# 	io.netty#netty-resolver;4.1.17.Final from central in [default]
# 	io.netty#netty-transport;4.1.17.Final from central in [default]
# 	jakarta.activation#jakarta.activation-api;1.2.1 from central in [default]
# 	jakarta.xml.bind#jakarta.xml.bind-api;2.3.3 from central in [default]
# 	javax.inject#javax.inject;1 from central in [default]
# 	javax.servlet#javax.servlet-api;3.1.0 from central in [default]
# 	javax.servlet.jsp#jsp-api;2.1 from central in [default]
# 	javax.ws.rs#javax.ws.rs-api;2.1.1 from central in [default]
# 	javax.ws.rs#jsr311-api;1.1.1 from central in [default]
# 	javax.xml.bind#jaxb-api;2.2.11 from central in [default]
# 	joda-time#joda-time;2.8.1 from central in [default]
# 	log4j#log4j;1.2.17 from central in [default]
# 	net.bytebuddy#byte-buddy;0.6.14 from central in [default]
# 	net.minidev#accessors-smart;2.4.7 from central in [default]
# 	net.minidev#json-smart;2.4.7 from central in [default]
# 	org.apache.avro#avro;1.7.7 from central in [default]
# 	org.apache.commons#commons-compress;1.21 from central in [default]
# 	org.apache.commons#commons-configuration2;2.1.1 from central in [default]
# 	org.apache.commons#commons-csv;1.1 from central in [default]
# 	org.apache.commons#commons-lang3;3.12.0 from central in [default]
# 	org.apache.commons#commons-math3;3.1.1 from central in [default]
# 	org.apache.commons#commons-text;1.4 from central in [default]
# 	org.apache.curator#curator-client;4.2.0 from central in [default]
# 	org.apache.curator#curator-framework;4.2.0 from central in [default]
# 	org.apache.curator#curator-recipes;4.2.0 from central in [default]
# 	org.apache.hadoop#hadoop-annotations;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-auth;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-common;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-hdfs-client;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-mapreduce-client-core;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-api;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-client;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-common;3.3.2 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_7;1.1.1 from central in [default]
# 	org.apache.httpcomponents#httpclient;4.5.13 from central in [default]
# 	org.apache.httpcomponents#httpcore;4.4.13 from central in [default]
# 	org.apache.kerby#kerb-admin;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-client;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-common;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-core;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-crypto;1.0.1 from spark-list in [default]
# 	org.apache.kerby#kerb-identity;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-server;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-simplekdc;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-util;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-asn1;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-config;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-pkix;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-util;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-xdr;1.0.1 from central in [default]
# 	org.apache.kerby#token-provider;1.0.1 from central in [default]
# 	org.apache.yetus#audience-annotations;0.5.0 from central in [default]
# 	org.apache.zookeeper#zookeeper;3.5.6 from central in [default]
# 	org.apache.zookeeper#zookeeper-jute;3.5.6 from central in [default]
# 	org.checkerframework#checker-qual;2.5.2 from central in [default]
# 	org.codehaus.jackson#jackson-core-asl;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-jaxrs;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-mapper-asl;1.9.13 from spark-list in [default]
# 	org.codehaus.jackson#jackson-xc;1.9.13 from spark-list in [default]
# 	org.codehaus.jettison#jettison;1.1 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.17 from central in [default]
# 	org.codehaus.woodstox#stax2-api;4.2.1 from central in [default]
# 	org.eclipse.jetty#jetty-client;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-http;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-io;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-security;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-server;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-servlet;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-util;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-webapp;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-xml;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-api;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-client;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-common;9.4.43.v20210629 from central in [default]
# 	org.jline#jline;3.9.0 from central in [default]
# 	org.mockito#mockito-core;2.0.31-beta from central in [default]
# 	org.objenesis#objenesis;2.1 from central in [default]
# 	org.ow2.asm#asm;5.0.4 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from central in [default]
# 	org.slf4j#slf4j-log4j12;1.7.30 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.8.2 from central in [default]
# 	software.amazon.ion#ion-java;1.0.2 from central in [default]
# 	:: evicted modules:
# 	org.apache.httpcomponents#httpclient;4.5.5 by [org.apache.httpcomponents#httpclient;4.5.13] in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.6.7 by [com.fasterxml.jackson.core#jackson-core;2.13.0] in [default]
# 	com.amazonaws#aws-java-sdk-simpleworkflow;1.11.22 by [com.amazonaws#aws-java-sdk-simpleworkflow;1.11.434] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |  279  |   0   |   0   |   3   ||  276  |   0   |
# 	---------------------------------------------------------------------
#
# :: problems summary ::
# :::: ERRORS
# 	unknown resolver user-list
#
# 	unknown resolver user-list
#
# 	unknown resolver user-list
#
# 	unknown resolver user-list
#
# 	unknown resolver user-list
#
# 	unknown resolver user-list
#
# 	unknown resolver user-list
#
# 	unknown resolver user-list
#
#
# :: USE VERBOSE OR DEBUG MESSAGE LEVEL FOR MORE DETAILS
# :: retrieving :: org.apache.spark#spark-submit-parent-752fd5bf-6faf-4c0e-b792-1e2c155f8cc9
# 	confs: [default]
# 	0 artifacts copied, 276 already retrieved (0kB/34ms)
# 24/09/06 16:52:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
from feathr import get_result_df
path = "s3a://feathrstore/df*/daily/2020/04/20/"
df = get_result_df(spark=spark,client=client, format="parquet", res_url=path)
df.show()
# Out:
# 24/09/06 16:52:19 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# +-------------------+-------------------+----+
# |f_location_avg_fare|f_location_max_fare|key0|
# +-------------------+-------------------+----+
# |          4270.7866|             7450.0| 227|
# |          1941.2174|             5705.0| 131|
# |           2707.024|             8000.0| 228|
# |          2698.0476|             6620.0| 100|
# |          1865.2667|             2988.0| 200|
# |             8237.0|             8237.0| 221|
# |          2041.9125|             7050.0| 241|
# |           1280.625|             4853.0| 207|
# |           1339.925|             4204.0| 135|
# |             4567.5|             5120.0| 118|
# |             5639.6|             6804.0| 201|
# |          1686.2034|             6106.0| 242|
# |          1714.4845|             5476.0| 177|
# |             1988.1|             4850.0| 144|
# |          2234.8262|             5563.0| 256|
# |             6620.0|             6620.0| 204|
# |           2951.254|             6257.0| 137|
# |          1944.0714|             6022.0| 218|
# |          1599.3903|             4320.0| 157|
# |          2046.4286|             3051.0| 184|
# +-------------------+-------------------+----+
# only showing top 20 rows

# %% [markdown]
# ## Cleanup

# %%
# TODO: Unregister, delete cached files or do any other cleanups.

# %%
# Stop the spark session if it is a local session.
if is_jupyter():
    spark.stop()

# %% [markdown]
# Scrap Variables for Unit-Test
